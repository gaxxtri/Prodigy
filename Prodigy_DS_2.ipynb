# %%
import pandas as pd

# Load the Titanic dataset
titanic_data = pd.read_csv("titanic.csv")

# Display the first few rows of the dataset
titanic_data.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                             Mr. Owen Harris Braund
# 1         1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2         1       3                              Miss. Laina Heikkinen
# 3         1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4         0       3                            Mr. William Henry Allen
#
#       Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# 0    male  22.0                        1                        0   7.2500
# 1  female  38.0                        1                        0  71.2833
# 2  female  26.0                        0                        0   7.9250
# 3  female  35.0                        1                        0  53.1000
# 4    male  35.0                        0                        0   8.0500

# %%
import piplite
await piplite.install('seaborn')
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# Visualization of Individual Variables
# Distribution of Age
plt.figure(figsize=(10, 6))
sns.histplot(titanic_data ['Age'], bins=30, kde=True)
plt.title('Age Distribution of Titanic Passengers')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# Count plot for gender
plt.figure(figsize=(8, 6))
sns.countplot(x='Sex', data=titanic_data)
plt.title('Gender Distribution of Titanic Passengers')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# Count plot for class
plt.figure(figsize=(8, 6))
sns.c(x='Pclass', data=titanic_data)
plt.title('Class Distribution of Titanic Passengers')
plt.xlabel('Class')
plt.ylabel('Count')
plt.show()

# Exploring relationships between variables
# Survival rate by gender
plt.figure(figsize=(8, 6))
sns.barplot(x='Sex', y='Survived', data=titanic_data)
plt.title('Survival Rate by Gender')
plt.xlabel('Gender')
plt.ylabel('Survival Rate')
plt.show()

# Survival rate by class
plt.figure(figsize=(8, 6))
sns.barplot(x='Pclass', y='Survived', data=titanic_data)
plt.title('Survival Rate by Class')
plt.xlabel('Class')
plt.ylabel('Survival Rate')
plt.show()

# Correlation heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(titanic_data.corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 25
#      23 # Count plot for class
#      24 plt.figure(figsize=(8, 6))
# ---> 25 sns.c(x='Pclass', data=titanic_data)
#      26 plt.title('Class Distribution of Titanic Passengers')
#      27 plt.xlabel('Class')
#
# AttributeError: module 'seaborn' has no attribute 'c'
